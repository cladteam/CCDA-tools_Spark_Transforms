# %%
import dq_ccda_snooper_people
from foundry.transforms import Dataset

# do the dataset code here in ipynb where Foundry can see it
ccda_response_files_dataset = Dataset.get("ccda_response_files")
ccda_snooper_people_df = dq_ccda_snooper_people.entry_point_2(ccda_response_files_dataset, True, True, limit=299)

dq_ccda_snooper_people_dataset = Dataset.get("dq_ccda_snooper_people")
dq_ccda_snooper_people_dataset.write_table(ccda_snooper_people_df)

# doesn't work as a transform that makes Foundry happy
#ccda_response_files="ccda_response_files"
#dq_ccda_snooper_people.entry_point(ccda_response_files, export_flag=True, write_flag=True )

      
print("done")
