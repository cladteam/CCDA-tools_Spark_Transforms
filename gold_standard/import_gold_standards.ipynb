# %%
import pandas as pd
from foundry.transforms import Dataset
gs_person_csv = pd.read_csv('gs_person.csv')
gs_person = Dataset.get("gs_person")
gs_person.write_table(gs_person_csv)

# %%
import pandas as pd
from foundry.transforms import Dataset
gs_visit_occurrence_csv = pd.read_csv('gs_visit_occurrence.csv')
gs_visit_occurrence = Dataset.get("gs_visit_occurrence")
gs_visit_occurrence.write_table(gs_visit_occurrence_csv)

# %%
import pandas as pd
from foundry.transforms import Dataset
gs_measurement_csv = pd.read_csv('gs_measurement.csv')
gs_measurement = Dataset.get("gs_measurement")
gs_measurement.write_table(gs_measurement_csv)

# %%
import pandas as pd
from foundry.transforms import Dataset
gs_observation_csv = pd.read_csv('gs_observation.csv')
gs_observation = Dataset.get("gs_observation")
gs_observation.write_table(gs_observation_csv)
