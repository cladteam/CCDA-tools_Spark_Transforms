# %%
import dq_ccda_snooper_section
import dq_ccda_snooper_section_simple

dataset_read  = "ccda_response_files"
dataset_write = "dq_ccda_snooper_section"
#dq_ccda_snooper_section.entry_point(dataset_read, dataset_write, export_flag=True, write_flag=True ),
dq_ccda_snooper_section.entry_point(dataset_read, dataset_write, export_flag=True, write_flag=True ),

print("done")
