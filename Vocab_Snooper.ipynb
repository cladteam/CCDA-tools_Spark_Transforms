# %%
import vocab_snooper.py

# emulating this command
# python3 -m prototype_2.layer_datasets -ds ccda_documents  -x

hard_coded_dataset_name="ccda_documents"
print("starting...")
layer_datasets.process_dataset(hard_coded_dataset_name, 0, 1)
      
print("done")
